# %%
l = [1,2]

# %%
l.index(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-00669e6b911d> in <module>()
# ----> 1 l.index(3)
#
# ValueError: 3 is not in list

# %%
def calcSum(n):
    s = 0
    if n == 0:
        return 1
    while (n!=0):
        d = n%10
        n = n/10
        s = s + F[d]
    return s

# %%
from collections import defaultdict
N,L = (10,7)
F = [1,1,2,6,24,120,720,5040,40320,362880 ,3628800]
cache = defaultdict(int)

# %%
def nextTerm(N):
    l = [N]
    while True:
        a = calcSum(N)
        try:
            ind = l.index(a)
            break
        except ValueError:
            l.append(a)
            N = a
            
    print l

# %%
nextTerm(7)
# Out:
# [7, 5040, 146, 745, 5184, 40465, 889, 443520, 177, 10081, 40324, 57, 5160, 842, 40346, 775, 10200, 6, 720, 5043, 151, 122, 5, 120, 4, 24, 26, 722, 5044, 169, 363601, 1454]

# %%
a = [1,2]

# %%
"".join(map(str,a))
# Out:
# '12'

# %%
l = {}
l[(0,1)] = 2

# %%
l
# Out:
# {(0, 1): 2}

# %%
l[(1,0)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-b398b4d7511b> in <module>()
# ----> 1 l[(1,0)]
#
# KeyError: (1, 0)

# %%
from collections import OrderedDict

# %%
d = {"d":"d","a":"a","b":"b","c":"c"}

# %%
d
# Out:
# {'a': 'a', 'b': 'b', 'c': 'c', 'd': 'd'}

# %%
s = '''{"2015-05-06T16:34:39.402-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:41:04.499-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:42:13.648-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:37:42.355-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:34:26.298-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:42:59.118-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:36:44.197-0400": [["184.66", "43.99", "laptop"]], "2015-05-06T16:41:48.628-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:35:09.456-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:42:31.968-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:43:05.925-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:39:07.901-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:38:42.010-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:37:24.618-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:38:25.903-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:34:35.103-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:38:35.117-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:38:32.775-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:37:15.376-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:38:12.118-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:38:23.583-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:34:17.681-0400": [["184.66", "43.99", "laptop"]], "2015-05-06T16:39:17.382-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:41:25.334-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:37:03.827-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:35:05.263-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:40:14.549-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:37:28.987-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:41:18.405-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:30:47.031-0400": [["181.95", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:35:44.056-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:37:26.786-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:37:22.310-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:43:14.686-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:41:02.198-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:40:55.288-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:42:29.664-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:30:38.268-0400": [["181.95", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:36:44.196-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:33:30.570-0400": [["184.66", "43.99", "laptop"]], "2015-05-06T16:32:56.233-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:39:44.971-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:41:13.721-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:39:26.582-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:33:51.699-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:38:58.096-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:37:58.463-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:34:17.680-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:31:17.231-0400": [["181.95", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:39:53.963-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:43:03.691-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:37:06.112-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:36:48.514-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:38:05.449-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:42:18.234-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:41:41.498-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:33:00.540-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:41:36.833-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:39:10.442-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:31:04.406-0400": [["181.95", "44.15", "android"]], "2015-05-06T16:39:33.527-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:38:37.439-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:31:34.476-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:36:26.972-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:41:32.257-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:36:59.221-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:39:21.941-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:38:46.578-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:37:33.630-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:34:09.006-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:32:34.805-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:35:39.756-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:38:21.300-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:42:38.865-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:31:00.059-0400": [["184.66", "43.99", "laptop"]], "2015-05-06T16:32:43.305-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:33:34.868-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:40:00.663-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:32:00.390-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:42:22.862-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:38:53.514-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:31:47.470-0400": [["184.66", "43.99", "laptop"]], "2015-05-06T16:32:51.941-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:36:05.481-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:36:31.323-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:35:31.136-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:42:34.274-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:30:42.806-0400": [["181.95", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:31:56.117-0400": [["184.66", "43.99", "laptop"]], "2015-05-06T16:40:07.680-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:31:30.216-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:41:16.078-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:43:01.394-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:42:02.250-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:32:13.402-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:38:14.440-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:38:30.470-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:32:09.076-0400": [["184.66", "43.99", "laptop"]], "2015-05-06T16:43:19.147-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:38:55.801-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:35:18.115-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:32:09.075-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:38:48.889-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:36:18.414-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16:38:16.701-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:32:26.253-0400": [["181.88", "44.15", "android"], ["184.66", "43.99", "laptop"]], "2015-05-06T16
0400": [["181.88", "44.15", "android"]], "2015-05-06T16:37:08.422-0400": [["181.88", "44.15", "android"]], "2015-05-06T16:41:11.467-0400": [["181.88", "44.15", "android"]]}
'''
import json

# %%
s1 = json.loads(s)

# %%
s1
# Out:
# {u'2015-05-06T16:30:38.268-0400': [[u'181.95', u'44.15', u'android'],
#   [u'184.66', u'43.99', u'laptop']],
#  u'2015-05-06T16:30:42.806-0400': [[u'181.95', u'44.15', u'android'],
#   [u'184.66', u'43.99', u'laptop']],
#  u'2015-05-06T16:30:47.031-0400': [[u'181.95', u'44.15', u'android'],
#   [u'184.66', u'43.99', u'laptop']],
#  u'2015-05-06T16:30:51.383-0400': [[u'181.95', u'44.15', u'android'],
#   [u'184.66', u'43.99', u'laptop']],
#  u'2015-05-06T16:30:55.768-0400': [[u'181.95', u'44.15', u'android'],
#   [u'184.66', u'43.99', u'laptop']],
#  u'2015-05-06T16:31:00.058-0400': [[u'181.95', u'44.15', u'android']],
#  u'2015-05-06T16:31:00.059-0400': [[u'184.66', u'43.99', u'laptop']],
#  u'2015-05-06T16:31:04.406-0400': [[u'181.95', u'44.15', u'android']],
#  u'2015-05-06T16:31:04.407-0400': [[u'184.66', u'43.99', u'laptop']],
#  u'2015-05-06T16:31:08.750-0400': [[u'181.95', u'44.15', u'android'],
#   [u'184.66', u'43.99', u'laptop']],
# ...

# %%
import datetime
d2 = OrderedDict(sorted(s1.items()))

# %%
d2
# Out:
# OrderedDict([(u'2015-05-06T16:30:38.268-0400', [[u'181.95', u'44.15', u'android'], [u'184.66', u'43.99', u'laptop']]), (u'2015-05-06T16:30:42.806-0400', [[u'181.95', u'44.15', u'android'], [u'184.66', u'43.99', u'laptop']]), (u'2015-05-06T16:30:47.031-0400', [[u'181.95', u'44.15', u'android'], [u'184.66', u'43.99', u'laptop']]), (u'2015-05-06T16:30:51.383-0400', [[u'181.95', u'44.15', u'android'], [u'184.66', u'43.99', u'laptop']]), (u'2015-05-06T16:30:55.768-0400', [[u'181.95', u'44.15', u'android'], [u'184.66', u'43.99', u'laptop']]), (u'2015-05-06T16:31:00.058-0400', [[u'181.95', u'44.15', u'android']]), (u'2015-05-06T16:31:00.059-0400', [[u'184.66', u'43.99', u'laptop']]), (u'2015-05-06T16:31:04.406-0400', [[u'181.95', u'44.15', u'android']]), (u'2015-05-06T16:31:04.407-0400', [[u'184.66', u'43.99', u'laptop']]), (u'2015-05-06T16:31:08.750-0400', [[u'181.95', u'44.15', u'android'], [u'184.66', u'43.99', u'laptop']]), (u'2015-05-06T16:31:13.045-0400', [[u'181.95', u'44.15', u'andr
# ...

# %%
with open("a.json","w+") as f:
    json.dump(d2,f)

# %%
from fractions import gcd

# %%
m = reduce(gcd,[2,4])

# %%
m
# Out:
# 2

# %%
import numpy as np

# %%
a = np.array([[1,2],[3,4]])

# %%
a[0][0]
# Out:
# 1

# %%
a[0][0] = "X"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-98b1147072fd> in <module>()
# ----> 1 a[0][0] = "X"
#
# ValueError: invalid literal for long() with base 10: 'X'

# %%
range(11/3 * 3,-1,-3)
# Out:
# [9, 6, 3, 0]

# %%
start = "a"
end = "b"

# %%
op(start)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-500e6cbbf333> in <module>()
# ----> 1 op(start)
#
# NameError: name 'op' is not defined

# %%
from math import fabs

# %%
fabs(-3)
# Out:
# 3.0

# %%
 i =36621
d = 2

# %%
s = str(i)
r = s[-1*d:]

# %%
r
# Out:
# '21'

# %%
l = s[0:len(s) - d]

# %%
l
# Out:
# '366'

# %%
s = [1,2,3]

# %%
avg(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-ef9c9aebcd76> in <module>()
# ----> 1 avg(s)
#
# NameError: name 'avg' is not defined

# %%
a = [1,1,0]
b = [0,0,1]

# %%
[b[i]^v for i,v in enumerate(a)]
# Out:
# [1, 1, 1]
